# %%
def insert_sort(A):
    for j in range(1, len(A)):
        key = A[j]
        i = j - 1
        while i >= 0 and A[i] > key:
            A[i+1] = A[i]
            i = i - 1
        A[i+1] = key

# %%
import numpy as np

# %%
def generate_random_array(arraySize):
    return np.random.randint(100, size = arraySize)

# %%
def generate_ascending_array(arraySize):
    return np.arange(arraySize)

# %%
def generate_descending_array(arraySize):
    return np.flip(np.arange(arraySize))

# %%
import time

# %%
def generate_best_measure(arraySize):
    arr = generate_ascending_array(arraySize)
    time_start = time.time()
    insert_sort(arr)
    time_end = time.time()
    return time_end - time_start

# %%
def generate_worst_measure(arraySize):
    arr = generate_descending_array(arraySize)
    time_start = time.time()
    insert_sort(arr)
    time_end = time.time()
    return time_end - time_start

# %%
def generate_average_measure(arraySize):
    arr = generate_random_array(arraySize)
    time_start = time.time()
    insert_sort(arr)
    time_end = time.time()
    return time_end - time_start

# %%
import matplotlib.pyplot as plt

# %%
def generate_average_measure_10(arraySize):
    total = 0
    for i in range(10):
        total += generate_average_measure(arraySize)
    return total / 10

# %%
arraySizes = [1, 10, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
arraySizes1 = [1, 10, 100, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
arraySizes2 = [1, 10, 100, 1000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]

# %%
def generate_data(sizes):
    dataList = []
    for size in sizes:
        dataTuple = (generate_best_measure(size), generate_average_measure_10(size), generate_worst_measure(size))
        dataList.append(dataTuple)
    return dataList

# %%
dataResults = generate_data(arraySizes)

# %%
plt.plot(arraySizes, dataResults)
plt.title("Insertion sort analysis")
plt.xlabel("Array size")
plt.ylabel("Time (s)")
plt.legend(["Best case","Average case","Worst case"])
plt.show()

# %%
def generate_best_data(sizes):
    dataList = []
    for size in sizes:
        data = generate_best_measure(size)
        dataList.append(data)
    return dataList

# %%
dataResultsBest = generate_best_data(arraySizes2)

# %%
plt.plot(arraySizes2, dataResultsBest)
